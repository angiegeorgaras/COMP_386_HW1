# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
from numpy import*
import numpy as np
from skimage import color
from skimage import io

# %%
def rgb2gray(rgb):
    return np.dot(rgb[...,:3], [0.299, 0.587, 0.114])

img = mpimg.imread('tree.jpg')     
gray = rgb2gray(img)    
plt.imshow(gray, cmap = plt.get_cmap('gray'))
plt.show()

# %%
def imageTo2DArray(img):
    temp=asarray(img)
    x=temp.shape[0]
    y=temp.shape[1]

    temp.resize((x,y)) # a 2D array
    print(temp)

# %%
imageTo2DArray(gray)
# Out:
# [[171.183 171.183 171.183 ... 171.906 171.906 171.906]
#  [171.183 171.183 171.183 ... 171.906 171.906 171.906]
#  [172.183 172.183 172.183 ... 172.906 172.906 172.906]
#  ...
#  [138.165 133.165 133.165 ... 133.077 132.806 132.806]
#  [136.165 132.165 133.165 ... 128.305 126.806 136.806]
#  [139.165 136.165 139.165 ... 123.305 121.806 128.806]]

# %%
def arrayToImage(array):
    plt.imshow(array, cmap="gray")
    plt.show()
    
arrayToImage([[3,4,5],[6,7,8]])
